# %% [markdown]
# # Naive Bayes

# %%
# file path exist
import os.path
from os import path

# translator
import googletrans
from googletrans import Translator

# pandas
import pandas as pd

# preprocessing of text
import re
import string
import nltk

# word tokenizer by nltk
from nltk import word_tokenize

# lemmatizer
from nltk.stem import WordNetLemmatizer

# stopwords (Remove buzz words)
from nltk.corpus import stopwords

# split data into train and test
from sklearn.model_selection import train_test_split

# bag of words
from sklearn.feature_extraction.text import CountVectorizer

# TF-IDF
from sklearn.feature_extraction.text import TfidfTransformer

# RFM classifier from scikit learn
from sklearn.svm import LinearSVC

# Tf-idf feature extraction 
from sklearn.feature_extraction.text import TfidfVectorizer

# confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

# cross validation for kfold
from sklearn.model_selection import cross_val_score

# calc accuracy
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
# original hindi file
filename  = '../Data/WelFake/WELFake_Dataset'
orig_df = pd.read_csv(filename + '.csv',  
               delimiter=',')
orig_df.drop(orig_df.columns[[0,1]], axis = 1, inplace = True)
orig_df["text"] = orig_df["text"].astype(str)
orig_df["label"] = orig_df["label"].astype(str)


# filename  = '../Data/WelFake/WELFake_Dataset'
# orig_df = pd.read_csv(filename + '.csv',  
#                delimiter=',')
# orig_df["text"] = orig_df["text"].astype(str)
# orig_df["label"] = orig_df["label"].astype(str)

# %%
df.head()
# Out:
#                                                 text label
# 0  No comment is expected from Barack Obama Membe...     1
# 1     Did they post their votes for Hillary already?     1
# 2   Now, most of the demonstrators gathered last ...     1
# 3  A dozen politically active pastors came here f...     0
# 4  The RS-28 Sarmat missile, dubbed Satan 2, will...     1

# %% [markdown]
# ### Class count

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,4))
df.groupby('label').text.count().plot.bar(ylim=0)
plt.show()
# Out:
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 153 (\x99) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 157 (\x9d) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 156 (\x9c) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 147 (\x93) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 152 (\x98) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# Font 'default' does not have a glyph for '\x80' [U+80], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\x93' [U+93], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\x99' [U+99], substituting with a dummy symbol.
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 145 (\x91) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 154 (\x9a) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 139 (\x8b) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 136 (\x88) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 143 (\x8f) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 140 (\x8c) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 149 (\x95) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 142 (\x8e) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 135 (\x87) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 158 (\x9e) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 138 (\x8a) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 141 (\x8d) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 132 (\x84) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 134 (\x86) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 137 (\x89) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 155 (\x9b) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 133 (\x85) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 159 (\x9f) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 144 (\x90) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 151 (\x97) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# Font 'default' does not have a glyph for '\x80' [U+80], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\x93' [U+93], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\x99' [U+99], substituting with a dummy symbol.

# %%
# For entire dataset sentences for each labels 
df.label.value_counts()
# Out:
# 1                                                                                                                                                                  37038
# 0                                                                                                                                                                  34980
#  or naturalization or by jus sanguinis â inherited through ancestors/parents                                                                                         6
#  etc.                                                                                                                                                                  5
#  Philippines                                                                                                                                                           4
#                                                                                                                                                                    ...
#  Ñ
# Ð¾ÑÑ ÐµÑÑ ÑÐ°Ð· ÑÐºÐ°Ð·Ð°ÑÑ. Ð®Ð³Ð¾ÑÐ»Ð°Ð²Ð¸Ñ                                                                                                             1
#  Ð²Ð¾Ð¾Ð±ÑÐµ Ð½Ð¸ Ð¾Ð´Ð¸Ð½ ÑÐµÐ»Ð¾Ð²ÐµÐº Ð½Ðµ Ð¿Ð¾Ð³Ð¸Ð±. ÐÐ´Ð¸Ð½ÑÑÐ²ÐµÐ½Ð½Ð¾Ðµ                                                                                   1
#  Ð° Ð¿Ð¾ÑÐ¾Ð¼ Ð¾Ñ Ð¡ÐµÑÐ±Ð¸Ð¸. Ð ÐÐ¾ÑÐ¾Ð²Ð¾ Ð¿Ð°ÑÐ»Ð°Ð¼ÐµÐ½Ñ Ð¿ÑÐ¾Ð³Ð¾Ð»Ð¾ÑÐ¾Ð²Ð°Ð» Ð¿Ð¾ÑÐ»Ðµ Ð²Ð¾ÐµÐ½Ð½ÑÑ
#  Ð´ÐµÐ¹ÑÑÐ²Ð¸Ð¹ Ð¸Ð½ÑÐµÑÐ²ÐµÐ½ÑÐ¸Ð¸        1
#  ÐÐµÐ»Ð³ÑÐ°Ð´Ð° Ð¸ ÐÑÑÐ¼Ð°. Ð¡Ð¿Ð°ÑÐ¸Ð±Ð¾ ÐÐ°Ð¼ Ð·Ð° ÑÐ°ÐºÐ¾Ð¹ Ð¿ÑÐ¸Ð¼ÐµÑ                                                                                    1
#  google                                                                                                                                                                1
# Name: label, Length: 1362, dtype: int64

# %%
#balancing data 
from collections import Counter
import numpy as np
def balanceClasses(xs, ys):
    item = {}
    new_ys = []
    new_xs = []
    #"""Undersample xs, ys to balance classes."""
    freqs = Counter(ys)
    # the most common class  is the maximum number we want for all classes
    max_allowable = (freqs.most_common()[0][1])
    
    for val in freqs.most_common(): # List
        nums = np.random.randint(1000)
        i = 1
        item[val[0]] = max_allowable - val[1]
        
        if item[val[0]] > 0:            
            while(item[val[0]] - i != 0): 
                nums = nums + 1
                if ys[nums] == val[0]:
                    i += 1
                    new_ys.append(ys[nums])
                    new_xs.append(xs[nums])
    return new_xs, new_ys

# %%
new_text, new_label = balanceClasses(df['Body'], df['Label'])

# %%
data = pd.DataFrame(new_text)
data.columns = ['Body']
data['Label'] = new_label
data = pd.concat([df, data])

# %%
fig1 = plt.figure(figsize=(6,4))
data.groupby('Label').Body.count().plot.bar(ylim=0)
plt.show()

# %%
data.Label.value_counts()
# Out:
# 0    2137
# 1    2136
# Name: Label, dtype: int64

# %%
data=data.sample(frac=1).reset_index(drop=True)
data
# Out:
#                                                    Body Label
# 0     The T20 Global League was seen as South Africa...     1
# 1     Photo\nIn 2010, 16-year-old Matteo Manassero o...     1
# 2     Story highlights Gloria Borger says administra...     1
# 3     Image copyright Alamy\nThe European Union has ...     1
# 4     Media playback is unsupported on your device M...     1
# ...                                                 ...   ...
# 4268  Chat with us in Facebook Messenger. Find out w...     1
# 4269  A Poor Chinese Intern May Have Been Forced To ...     0
# 4270  FILE PHOTO: The logo of French gas and power g...     1
# 4271  Week 4 Rankings (2017): Top 40 Running Backs: ...     0
# 4272  Formula One F1 - Japanese Grand Prix 2017 - Su...     1
#
# [4273 rows x 2 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# People usually join sentences using more than one colon 

def ReplaceDoubleColon(inputString):
    return inputString.replace("..", " ") 

data['Body'] = data['Body'].apply(lambda x: ReplaceDoubleColon(x))

def ReplaceTripleColon(inputString):
    return inputString.replace("...", " ") 

data['Body'] = data['Body'].apply(lambda x: ReplaceTripleColon(x))

def ReplaceFourColon(inputString):
    return inputString.replace("....", " ") 

data['Body'] = data['Body'].apply(lambda x: ReplaceFourColon(x))

# %%
def textPattern(text):

    # Clean the text
    text = re.sub(r"@", " ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", "have", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"aren't", "are not", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"didn't", "did not", text)
    text = re.sub(r"doesn't", "does not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"hadn't", "had not", text)
    text = re.sub(r"hasn't", "has not", text)
    text = re.sub(r"haven't", "have not", text)
    text = re.sub(r"isn't", "is not", text)
    text = re.sub(r"shouldn't", "should not", text)
    text = re.sub(r"wasn't", "was not", text)
    text = re.sub(r"weren't", "were not", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"wouldn't", "would not", text)
    text = re.sub(r"mustn't", "must not", text)
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"\'re", "are", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\= =", " ", text)
    text = re.sub(r"\==", " ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"\s{2,}", " ", text)
    return text

data['Body'] = data['Body'].apply(lambda x: textPattern(x))

# %%
# Word Tokenization
tokens = [word_tokenize(sen) for sen in data.Body]

# %%
# Lower Case
def lower_token(tokens): 
    return [w.lower() for w in tokens]    
    
lower_tokens = [lower_token(token) for token in tokens]

# %%
# Remove Link

def removeLink(token):
    word = []
    for w in token:
        if not w.startswith('http'):
            word.append(w)
    return word 
    
removedLink_tokens = [removeLink(token) for token in lower_tokens]

# %%
# Word Lemmatization
def lemmatization(token):
    return [lemmatizer.lemmatize(w) for w in token] 

lemmatizer = WordNetLemmatizer()

lemmatized_tokens = [lemmatization(token) for token in removedLink_tokens]

# %%
# Removing Stopwords
stoplist = stopwords.words('english')

# %%
def removeStopWords(tokens): 
    return [word for word in tokens if word not in stoplist]

filtered_words = [sen for sen in lemmatized_tokens]
data['Text_Final'] = [' '.join(sen) for sen in filtered_words]
data['tokens'] = filtered_words

# %%
zero  = []
one = []
for l in data.Label:
    
    if l == '0':
        zero.append(1)
        one.append(0)
    elif l == '1':
        zero.append(0)
        one.append(1)
        
data['0']= zero
data['1']= one

data = data[['Text_Final', 'tokens', 'Label', '0', '1']]

# %%
category_id = []
for l in data.Label:
    
    if l == '0':
        category_id.append('0')
    elif l == '1':
        category_id.append('1')
        
data['Category_id'] = category_id

data = data[['Text_Final', 'tokens', 'Label', '0', '1', 'Category_id' ]]
data.head(25)
# Out:
#                                            Text_Final  \
# 0   the t20 global league wa seen a south africa s...
# 1   photo in 2010 16 - year - old matteo manassero...
# 2   story highlight gloria borger say administrati...
# 3   image copyright alamy the european union ha la...
# 4   medium playback is unsupported on your device ...
# 5   a potato battery can light up a room for over ...
# 6   by massprivatei are you looking forward to the...
# 7   an embattled pharmaceutical company that sell ...
# 8   by nicholas west a new type of court case is s...
# 9   no getting around it the war is coming trump o...
# 10  vielha spain ( reuters ) - if catalonia declar...
# 11  `` saturday night live '' kicked off it latest...
# 12  bump stock used by la vega shooter lauded by n...
# 13  by derrick broze an appeal court in washington...
# 14  red lobster customer make bomb joke to hostess...
# 15  a potato battery can light up a room for over ...
# 16  photo : what a shot 32 amazing sport photo slo...
# 17  [ gard align= center ] by aaron kesel the wash...
# 18  a potato battery can light up a room for over ...
# 19  just shut up & play some damn baseball ( befor...
# 20                                                nan
# 21  raider throw game to punish qb who wouldn ’ t ...
# 22  an embattled pharmaceutical company that sell ...
# 23  story highlight a woman say the alleged assaul...
# 24  medium playback is unsupported on your device ...
#
#                                                tokens Label  0  1 Category_id
# 0   [the, t20, global, league, wa, seen, a, south,...     1  0  1           1
# 1   [photo, in, 2010, 16, -, year, -, old, matteo,...     1  0  1           1
# 2   [story, highlight, gloria, borger, say, admini...     1  0  1           1
# 3   [image, copyright, alamy, the, european, union...     1  0  1           1
# 4   [medium, playback, is, unsupported, on, your, ...     1  0  1           1
# 5   [a, potato, battery, can, light, up, a, room, ...     0  1  0           0
# 6   [by, massprivatei, are, you, looking, forward,...     0  1  0           0
# 7   [an, embattled, pharmaceutical, company, that,...     0  1  0           0
# 8   [by, nicholas, west, a, new, type, of, court, ...     0  1  0           0
# 9   [no, getting, around, it, the, war, is, coming...     0  1  0           0
# 10  [vielha, spain, (, reuters, ), -, if, cataloni...     1  0  1           1
# 11  [``, saturday, night, live, '', kicked, off, i...     1  0  1           1
# 12  [bump, stock, used, by, la, vega, shooter, lau...     0  1  0           0
# 13  [by, derrick, broze, an, appeal, court, in, wa...     0  1  0           0
# 14  [red, lobster, customer, make, bomb, joke, to,...     0  1  0           0
# 15  [a, potato, battery, can, light, up, a, room, ...     0  1  0           0
# 16  [photo, :, what, a, shot, 32, amazing, sport, ...     1  0  1           1
# 17  [[, gard, align=, center, ], by, aaron, kesel,...     0  1  0           0
# 18  [a, potato, battery, can, light, up, a, room, ...     0  1  0           0
# 19  [just, shut, up, &, play, some, damn, baseball...     0  1  0           0
# 20                                              [nan]     0  1  0           0
# 21  [raider, throw, game, to, punish, qb, who, wou...     0  1  0           0
# 22  [an, embattled, pharmaceutical, company, that,...     0  1  0           0
# 23  [story, highlight, a, woman, say, the, alleged...     1  0  1           1
# 24  [medium, playback, is, unsupported, on, your, ...     1  0  1           1

# %%
data = data[data.tokens != '']

# %%
from io import StringIO
category_id_df = data[['Label', 'Category_id']].drop_duplicates().sort_values('Category_id')
category_to_label_dict = dict(category_id_df.values)
label_to_category_dict = dict(category_id_df[['Category_id', 'Label']].values)

# %% [markdown]
# #### Split Data into test and train
# We will use 90 % data for training and 10 % for testing. We use random state so every time we get the same training and testing data.

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# We referred a blog on Multi class classification for SVM and RFM [2]

# %% [markdown]
# ### Generating features using TF-IDF Vectorizer method

# %%
vectorizer = TfidfVectorizer(sublinear_tf=True, min_df=2, norm='l2', encoding='latin-1', ngram_range=(1, 3), stop_words='english')
features = vectorizer.fit_transform(data.Text_Final).toarray()
labels = data.Label
features.shape
# Out:
# (4273, 504276)

# %% [markdown]
# ### Spliting data 90/ 10

# %%
# Using similar split as CNN model
X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(features, labels, data.index, test_size=0.10, random_state=82)

# %% [markdown]
# ### GNB - Generating model

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
clf = model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# ###  GNB - Displaying false-positive rate (FPR) and true positive rate (TPR)

# %%
from sklearn.metrics import confusion_matrix
print("                          Gaussian Naive Bayes Method")
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap ='YlGnBu',
            xticklabels=category_id_df.Label.values, yticklabels=category_id_df.Label.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
#                           Gaussian Naive Bayes Method

# %% [markdown]
# ### GNB - Precision, Recall and F1-Score to quantify the quality of our model using a confusion matrix

# %%
results = confusion_matrix(y_test, y_pred)
print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred))
print ('Report : ')
print (classification_report(y_test, y_pred))
# Out:
# Confusion Matrix :
# [[191  28]
#  [  0 209]]
# Accuracy Score : 0.9345794392523364
# Report :
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93       219
#            1       0.88      1.00      0.94       209
#
#     accuracy                           0.93       428
#    macro avg       0.94      0.94      0.93       428
# weighted avg       0.94      0.93      0.93       428

# %% [markdown]
# # GNB - BOW

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
features1 = count_vect.fit_transform(data.Text_Final).toarray()
labels = data.Label
features1.shape
# Out:
# (4273, 41487)

# %%
# Using similar split 90/10
X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(features1, labels, data.index, test_size=0.10, random_state=72)

# %%
# generate Gaussian Naive Bayes model
model2 = GaussianNB()
clf2 = model2.fit(X_train, y_train)
y_pred2 = model2.predict(X_test)

# %% [markdown]
# ###  GNB - BOW - Displaying false-positive rate (FPR) and true positive rate (TPR)

# %%
from sklearn.metrics import confusion_matrix
print("                     Gaussian Naive Bayes Method - BOW")
conf_mat = confusion_matrix(y_test, y_pred2)
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap="YlGnBu",
            xticklabels=category_id_df.Label.values, yticklabels=category_id_df.Label.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
#                      Gaussian Naive Bayes Method - BOW

# %% [markdown]
# ### GNB - BOW - Precision, Recall and F1-Score to quantify the quality of our model using a confusion matrix.

# %%
results2 = confusion_matrix(y_test, y_pred2)
print ('Confusion Matrix :')
print(results2) 
print ('Accuracy Score :',accuracy_score(y_test, y_pred2))
print ('Report : ')
print (classification_report(y_test, y_pred2))
# Out:
# Confusion Matrix :
# [[194  19]
#  [ 13 202]]
# Accuracy Score : 0.9252336448598131
# Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92       213
#            1       0.91      0.94      0.93       215
#
#     accuracy                           0.93       428
#    macro avg       0.93      0.93      0.93       428
# weighted avg       0.93      0.93      0.93       428

# %% [markdown]
# ### GNB with BOW kfold

# %%
# for tfidf

import seaborn as sns
results=pd.DataFrame()
dictionary=dict()
dictionary['Evaluation Measures']=["K Fold", "Precision", "Recall", "F1 Score"]
dictionary['Naive Bayes - TFIDF']=[91.8, 92, 92, 92]
results=pd.DataFrame(dictionary)
sns.set_style(style="whitegrid")
ax = sns.barplot(x='Evaluation Measures', y= 'Naive Bayes - TFIDF',data=results)

# %%
# for BOW
import seaborn as sns
results=pd.DataFrame()
dictionary=dict()
dictionary['Evaluation Measures']=["K Fold", "Precision", "Recall", "F1 Score"]
dictionary['Naive Bayes - BOW']=[82.6, 83, 82, 82]
results=pd.DataFrame(dictionary)
sns.set_style(style="whitegrid")
ax = sns.barplot(x='Evaluation Measures', y= 'Naive Bayes - BOW',data=results)

# %% [markdown]
# ### Reference

# %% [markdown]
# [1] Multi-Class Text Classification with Scikit-Learn by Susan Li

# %% [markdown]
# [2] Scikit-Learn Documentation https://scikit-learn.org/
